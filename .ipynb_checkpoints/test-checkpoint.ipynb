# %%
import numpy as np
from matplotlib import pylab as plt
from importlib import reload

from gradient_approximation import *
from optimizers import *
from sets import *
from utils import *
from run_experiments import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
func_name = "quadratic"
d = 100
L = 1000
mu = 1
sigma = 0

args = init_experiment(func_name, d, seed=18, L=L, mu=mu)
## тоже наверно надо в run_experiments
sett = L2Ball(radius=1)
x_0 = np.random.random(size=d)
x_0 = x_0 / np.linalg.norm(x_0)

# %% [markdown]
# ## Finding x_sol

# %%
def learning_rate(k):
    return 1./(k+1000)

# %%
oracle = ZO_oracle(func_name, sigma, oracle_mode="tpf", args=args)
TrueGradient = TrueGradientApproximator(func_name, args=args) 
GD = GDOptimizer(TrueGradient, learning_rate, x_0, sett, max_oracle_calls=10**4)
GD.optimize()
# Out:
# 100%|██████████| 10000/10000 [00:00<00:00, 18288.60it/s]

# %%
make_err_plot([GD], labels=["GD via true gradient"], title='Finding x_sol')
x_sol = GD.x_curr

# %% [markdown]
# ## Разные аппроксиматоры для GD

# %%
def learning_rate_jaguar(k):
    return 1./(k + 8 * d**2)

def learning_rate_lame(k):
    return 1. / L

def learning_rate_turtle(k):
    return 1./(k + 8 * d)

# %%
Jaguar = JaguarApproximator(oracle, gamma=1e-5)
Lame = LameApproximator(oracle, gamma=1e-5)
Turtle = TurtleApproximator(oracle, gamma=1e-5)
approx_list = [Jaguar, Lame, Turtle]
#approx_list = [Lame]
lr_list = [learning_rate_jaguar, learning_rate_lame, learning_rate_turtle]
#lr_list = [learning_rate_lame]

optimizers_list = []
for approximator, lr in zip(approx_list, lr_list):
    opt = GDOptimizer(approximator, lr, x_0, sett, x_sol=x_sol, max_oracle_calls=10**4)
    opt.optimize()
    optimizers_list.append(opt)
# Out:
#   0%|          | 0/4951 [00:00<?, ?it/s]
# 100%|██████████| 4951/4951 [00:01<00:00, 3530.23it/s]
# 100%|██████████| 5000/5000 [00:01<00:00, 3750.10it/s]
# 100%|██████████| 100/100 [00:02<00:00, 44.73it/s]

# %%
make_err_plot(optimizers_list)

# %% [markdown]
# ## Разные аппроксиматоры для FW

# %%
def learning_rate_jaguar(k):
    return 1./(k + 8 * d**2)

def learning_rate_lame(k):
    return 10. / L

def learning_rate_turtle(k):
    return 1./(k + 8 * d)

# %%
Jaguar = JaguarApproximator(oracle, gamma=1e-5)
Lame = LameApproximator(oracle, gamma=1e-5)
Turtle = TurtleApproximator(oracle, gamma=1e-5)
approx_list = [Jaguar, Lame, Turtle]
#approx_list = [Lame]
lr_list = [learning_rate_lame, learning_rate_lame, learning_rate_lame]
#lr_list = [learning_rate_lame]

optimizers_list = []
for approximator, lr in zip(approx_list, lr_list):
    opt = FWOptimizer(approximator, lr, x_0, sett, x_sol=x_sol, max_oracle_calls=10**4)
    opt.optimize()
    optimizers_list.append(opt)
# Out:
#   0%|          | 0/4951 [00:00<?, ?it/s]
# 100%|██████████| 4951/4951 [00:01<00:00, 3361.49it/s]
# 100%|██████████| 5000/5000 [00:01<00:00, 3700.58it/s]
#  74%|███████▍  | 74/100 [00:01<00:00, 43.26it/s]
# Precision 1e-06 achieved at step 74!

# %%
make_err_plot(optimizers_list)

# %%
#

# %% [markdown]
# # LogReg or smth idk...

# %%
dataset = "mushrooms.txt" 
from sklearn.datasets import load_svmlight_file
data = load_svmlight_file(dataset)
X, y = data[0].toarray(), data[1]
n, d = X.shape
y = y * 2 - 3
matrix = X * np.expand_dims(y, axis=1)

# %%
func_name = "mushrooms"
d = 112
seed = 18
sigma = 0
sett = L2Ball(radius=1)

args = init_experiment(func_name, d, sigma=sigma)

x_0 = np.random.random(size=d)
x_0 = x_0 / np.linalg.norm(x_0)

# %%
def learning_rate(k):
    return 1./(k+1000)

# %%
oracle = ZO_oracle(func_name, sigma, oracle_mode="tpf", args=args)
TrueGradient = TrueGradientApproximator(func_name, args=args) 
GD = GDOptimizer(TrueGradient, learning_rate, x_0, sett, max_oracle_calls=10**4)
GD.optimize()
# Out:
#   0%|          | 6/10000 [00:00<07:19, 22.75it/s]
# 100%|██████████| 10000/10000 [02:17<00:00, 72.65it/s]

# %%
make_err_plot([GD], labels=["GD via true gradient"], title='Finding x_sol')
x_sol = GD.x_curr

# %%
def learning_rate_jaguar(k):
    return 1./(k + 8 * d**2)

def learning_rate_lame(k):
    return 1. / L

def learning_rate_turtle(k):
    return 1./(k + 8 * d)

# %%
Jaguar = JaguarApproximator(oracle, gamma=1e-5)
Lame = LameApproximator(oracle, gamma=1e-5)
Turtle = TurtleApproximator(oracle, gamma=1e-5)
approx_list = [Jaguar, Lame, Turtle]
#approx_list = [Lame]
lr_list = [learning_rate_jaguar, learning_rate_lame, learning_rate_turtle]
#lr_list = [learning_rate_lame]

optimizers_list = []
for approximator, lr in zip(approx_list, lr_list):
    opt = GDOptimizer(approximator, lr, x_0, sett, x_sol=x_sol, max_oracle_calls=10**4)
    opt.optimize()
    optimizers_list.append(opt)
# Out:
#   0%|          | 0/4945 [00:00<?, ?it/s]
#   0%|          | 0/4945 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /Users/vladislavminashkin/Documents/Project/Frank_Wolfe/test.ipynb Cell 23 line 1
#      <a href='vscode-notebook-cell:/Users/vladislavminashkin/Documents/Project/Frank_Wolfe/test.ipynb#X46sZmlsZQ%3D%3D?line=9'>10</a> for approximator, lr in zip(approx_list, lr_list):
#      <a href='vscode-notebook-cell:/Users/vladislavminashkin/Documents/Project/Frank_Wolfe/test.ipynb#X46sZmlsZQ%3D%3D?line=10'>11</a>     opt = GDOptimizer(approximator, lr, x_0, sett, x_sol=x_sol, max_oracle_calls=10**4)
# ---> <a href='vscode-notebook-cell:/Users/vladislavminashkin/Documents/Project/Frank_Wolfe/test.ipynb#X46sZmlsZQ%3D%3D?line=11'>12</a>     opt.optimize()
#      <a href='vscode-notebook-cell:/Users/vladislavminashkin/Documents/Project/Frank_Wolfe/test.ipynb#X46sZmlsZQ%3D%3D?line=12'>13</a>     optimizers_list.append(opt)
#
# File ~/Documents/Project/Frank_Wolfe/optimizers.py:84, in GDOptimizer.optimize(self)
#      82 self.errors_list = [1.]
#      83 for k in tqdm.trange(num_iter):
# ---> 84     self.x_curr, oracle_calls = self.step(self.x_curr, k)
#      85     self.oracle_calls_list.append(self.oracle_calls_list[-1] + oracle_calls)
#      86     error = self.get_error(self.x_curr) / self.R0
#
# File ~/Documents/Project/Frank_Wolfe/optimizers.py:52, in GDOptimizer.step(self, x, k)
#      50 def step(self, x, k):
#      51     gamma_k = self.learning_rate_k(k)
# ---> 52     nabla_f, oracle_calls = self.gradient_approximator.approx_gradient(x, k)
#      53     x_next = x - gamma_k * nabla_f
#      54     x_next = self.set.projection(x_next)
#
# File ~/Documents/Project/Frank_Wolfe/gradient_approximation.py:120, in JaguarApproximator.approx_gradient(self, x, k)
#     117     point_1 = x + self.gamma * e_i
#     118     point_2 = x - self.gamma * e_i
# --> 120     func_1, func_2 = self.ZO_oracle.get_points(point_1, point_2)
#     121     self.h_curr += (func_1 - func_2) / (2. * self.gamma) * e_i
#     123 self.g_curr = np.copy(self.h_curr)
#
# File ~/Documents/Project/Frank_Wolfe/gradient_approximation.py:66, in ZO_oracle.get_points(self, point_1, point_2)
#      63         func_2 = utils.logreg_func(point_2, matrix=self.matrix+matrix_noise_2)
#      65 if point_2 is not None:
# ---> 66     return func_1, func_2
#      67 else:
#      68     return func_1
#
# UnboundLocalError: cannot access local variable 'func_2' where it is not associated with a value

# %%
import importlib
importlib.reload(gradient_approximation)
# Out:
# <module 'gradient_approximation' from '/Users/vladislavminashkin/Documents/Project/Frank_Wolfe/gradient_approximation.py'>
